# %% [markdown]
# <a href="https://colab.research.google.com/github/hsoni7115/Techneeds_Machinelearning_2023/blob/main/HARSHITA_SONI_AIML(SEM_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Are there any null values in the dataset?if yes then fill them..

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('DelhiNCR Restaurants.csv')

# %%
data.isnull().sum()
# Out:
# Restaurant_Name            0
# Category                   0
# Pricing_for_2              0
# Locality                   0
# Dining_Rating              0
# Dining_Review_Count        0
# Delivery_Rating          402
# Delivery_Rating_Count      0
# Website                    0
# Address                    0
# Phone_No                   0
# Latitude                   0
# Longitude                  0
# Known_For2               405
# Known_For22              841
# dtype: int64

# %%
data['Delivery_Rating'].value_counts()
# Out:
# 3.9    304
# 4.0    264
# 4.1    253
# 4.2    177
# 3.8    140
# 4.3    135
# 3.7     99
# 3.6     60
# 3.5     50
# 4.4     26
# 3.4     20
# 3.3     11
# 4.5      8
# 3.2      6
# 3.1      5
# 3.0      3
# 2.8      1
# 2.9      1
# Name: Delivery_Rating, dtype: int64

# %%
data['Known_For2'].value_counts()
# Out:
# Get a complimentary night, earn up to 50% of spends as points at 250+ restaurants & much more. Know more    15
# Finger Food, Continental, Mediterranean, Italian, Asian                                                      9
# Continental, Italian, Fast Food, North Indian, Beverages, Coffee                                             7
# Chinese, Asian, Continental, North Indian, Beverages                                                         2
# Butterscotch Pastry, Truffle Pastry, Chocolate Truffle Cake, Pastries, Waffle, Cakes                         2
#                                                                                                             ..
# Passion Fruit Ice Tea, Cardamom Tea, Bun Tikki, Earl Grey Tea, Rose Tea, Smoked Chicken Pasta                1
# Chicken Crostini, Blackberry Mojito, Butter Maggi, Peri Fries, Masala Tea, Hot Coffee                        1
# ...

# %%
data['Known_For22'].value_counts()
# Out:
# Pretty Decor, Perfect Presentation, Tamper Proof Packaging, Worth the Money, Packing, Food Quality                     2
# Artistic Decor, The Service, Natural Ambience, Fusion Menu, Serene Ambience, Fusion Food                               1
# Excellent Place, Great Value, Nice Service, Recommended Place, Good Quality Food, Amazing Taste                        1
# Amazing Food and Experience, Delivery Instructions, Genuine Price, Faster Delivery, Worth the Price, Food Packaging    1
# Budget Food, Good for Large Groups, Packed on Weekends, Portions, Good Taste, Main Course                              1
#                                                                                                                       ..
# Classy Decor, Wonderful Service, Chinese, Server, Excellent Food, Hospitality                                          1
# Pocket Friendly, Nice Crowd, Great Ambiance, Polite Staff, Prompt Service, Worth the Money                             1
# ...

# %%
data=data.fillna({'Known_For22':'Pretty Decor, Perfect Presentation, Tamper Proof Packaging, Worth the Money, Packing, Food Quality', 'Known_For2':'Get a complimentary night, earn up to 50% of spends as points at 250+ restaurants & much more. Know more ' , 'Delivery_Rating' : '3.9' })

# %% [markdown]
# 3 COLIMNS - Known_For22,Known_For2,Delivery_Rating had null values which have been filled.

# %% [markdown]
# Q2.Which restaurant is the best one having ratings more than 4.5 for delivery?

# %%
data = pd.read_csv('DelhiNCR Restaurants.csv')

# %%
new_data=data[data['Delivery_Rating']>4.5]
new_data
# Out:
# Empty DataFrame
# Columns: [Restaurant_Name, Category, Pricing_for_2, Locality, Dining_Rating, Dining_Review_Count, Delivery_Rating, Delivery_Rating_Count, Website, Address, Phone_No, Latitude, Longitude, Known_For2, Known_For22]
# Index: []

# %% [markdown]
# NO RESTAURANT HAS RATING MORE THAN 4.5 FOR DELIVERY

# %% [markdown]
# Q3.What type of food is most preffered by the customers?

# %%
data['Category'].value_counts()
# Out:
# North Indian                                                      88
# North Indian, Chinese                                             39
# North Indian, Mughlai                                             37
# Pizza, Fast Food                                                  19
# North Indian, Chinese, Mughlai                                    17
#                                                                   ..
# North Indian, Kebab, Mughlai, Biryani, Beverages                   1
# North Indian, Continental, Italian, Chinese                        1
# North Indian, Continental, Asian, Chinese                          1
# Afghan, Iranian, Awadhi, Beverages                                 1
# Cafe, North Indian, Chinese, Kashmiri, Rolls, Pizza, Beverages     1
# Name: Category, Length: 1355, dtype: int64

# %% [markdown]
# NORTH INDIAN FOOD IS MOST PREFFERED BY CUSTOMERS

# %% [markdown]
# 4.How many people prefer delivery rather than dining ?

# %%
data.plot(y=["Delivery_Rating_Count","Dining_Review_Count"])
# Out:
# <Axes: >

# %% [markdown]
# Q5.Which restaurant is the best one having ratings more than 4.5 for dining?

# %%
data = pd.read_csv('DelhiNCR Restaurants.csv')

# %%
new_data1=data[data['Dining_Rating']>4.5]
new_data1
# Out:
#                   Restaurant_Name  \
# 0                        Rustom's
# 1                       Cafe Lota
# 2          Dum-Pukht - ITC Maurya
# 3                     Burma Burma
# 4                   The Big Chill
# ..                            ...
# 82  Green House - The Beer Garden
# 83                       Big Wong
# 84                La Pino'z Pizza
# 85                       The Hook
# 86                     Rahul Eggs
#
#                                              Category  Pricing_for_2  \
# 0   Parsi, Street Food, North Indian, Desserts, Be...           2100
# 1         Cafe, South Indian, North Indian, Beverages           1200
# 2                     Mughlai, North Indian, Desserts           5000
# 3         Asian, Burmese, Bubble Tea, Desserts, Salad           1600
# 4                      Continental, American, Italian           1500
# ..                                                ...            ...
# ...

# %% [markdown]
# THESE RESTAURANTS HAVE DINING RATINGS MORE THAN 4.5

# %% [markdown]
# Q6.Compare different delivery rating counts of different restaurants. Also tell that which restaurants has got the highest rating counts. Do this by creating a barplot

# %%
data = pd.read_csv('DelhiNCR Restaurants.csv')

# %%
df2=data.head(n=10)
df2
# Out:
#                  Restaurant_Name  \
# 0                       Rustom's
# 1                      Cafe Lota
# 2         Dum-Pukht - ITC Maurya
# 3                    Burma Burma
# 4                  The Big Chill
# 5                  Carnatic Cafe
# 6  Cocktails & Dreams, Speakeasy
# 7              Natural Ice Cream
# 8   Kuremal Mohan Lal Kulfi Wale
# 9                     Juggernaut
#
#                                             Category  Pricing_for_2  \
# 0  Parsi, Street Food, North Indian, Desserts, Be...           2100
# 1        Cafe, South Indian, North Indian, Beverages           1200
# 2                    Mughlai, North Indian, Desserts           5000
# 3        Asian, Burmese, Bubble Tea, Desserts, Salad           1600
# 4                     Continental, American, Italian           1500
# 5                                       South Indian            600
# 6                       Nepalese, Tibetan, Beverages           2500
# ...

# %%
df2.plot.bar(x="Restaurant_Name", y=["Delivery_Rating_Count"])
plt.show()
